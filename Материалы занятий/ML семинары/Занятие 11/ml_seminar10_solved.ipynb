# %% [markdown]
# # Сверточные сети и Transfer learning
#
# Цель этого ноутбука - знакомство со сверточными сетями и transfer learning на примере классификации картинок.
# План семинара:
#
# * Convolution, Pooling - базовые слои, их гиперпараметры и интуиция использования;
#
# * Построение сверточной нейросети для классификации картинок;
#
# * Использование Transfer Learning для этой же задачи.

# %%
import os
import time
import glob
import requests
from tqdm.notebook import tqdm
from collections import defaultdict

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

import torch
from torch import nn
import torch.nn.functional as F
from torchsummary import summary

import torchvision
from torchvision import transforms

from IPython.display import clear_output
# %matplotlib inline

sns.set(font_scale=1.2)
# sns.set_style(style='whitegrid')
device_num = 0
torch.cuda.set_device(device_num)

# %%
device = f"cuda:{device_num}" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# ### Convolution (свёртка)
#
# Основные гиперпараметры:
#
# * `in_channels` (int) - количество каналов во входном изображении
#
# * `out_channels` (int) - количество каналов после применения свертки (кол-во ядер (фильтров), которые будут применены)
#
# * `kernel_size` (int, tuple) - размер сверточного ядра
#
# * `stride` (int, tuple) - шаг, с которым будет применена свертка. Значение по умолчанию 1
#
# * `padding` (int, tuple) - добавление по краям изображения дополнительных пикселей. Значение по умолчанию 0
#
# * `padding_mode` (string, optional) - принцип заполнения краёв. Значение по умолчанию 'zeros'
#
# `nn.Conv2d(in_channels=1, out_channels=1, kernel_size=3, stride=2, padding=1, padding_mode='zeros')`
#  ![](http://deeplearning.net/software/theano/_images/numerical_padding_strides.gif)
#
#  Берем `out_channels` фильтров размера  `in_channels` x `kernel_size` x `kernel_size`. Каждым фильтром 'проходим' по изображению с шагом `stride`, поэлементно умножаем его на область изображения размером `in_channels` x `kernel_size` x `kernel_size`, складываем получившиеся поэлемнетные произведения и записываем это число в результирующий тензор. В итоге получаем `out_channels` выходных тензоров.
#
#  **Интуиция**:
#
# В FC слоях мы соединяли нейрон с каждым нейроном на предыдущем слое. Теперь нейрон соединен только с ограниченной областью выхода предыдущего слоя. Иногда эту область называют *рецептивном полем (receiptive field)* нейрона.
#
# Такое изменение необходимо из-за большой размерности входных данных. Например, если размер входного изображения $3 \cdot 224 \cdot 224$, то каждый нейроне в FC-слое будет содержать $3\cdot 224\cdot 224=150\:528$ параметров, что очень много. При этом мы захотим добавить нелинейности в нашу архитектуру, так что у нас будет несколько таких слоёв.

# %% [markdown]
# *Задача на понимание:*
#
# К изображению (3, 224, 224) применяют свертку `nn.Conv2d(in_channels=3, out_channels=64, kernel_size=5, stride=2, padding=2)`.
#
# * Какой будет размер выходного изображения?
#
# * Cколько у данного слоя обучаемых параметров?
#
# *Проверяем себя:*

# %%
model = nn.Sequential()
model.add_module('conv1', nn.Conv2d(in_channels=3, out_channels=64, 
                                    kernel_size=5, stride=2, padding=2))

# from torchsummary import summary

# summary(model.to(device), (3, 224, 224))

# %% [markdown]
# Посмотрим на то, как применение свёртки с определёнными фильтрами влияет на изображение и как будет меняться картинка в зависимости от фильтра:

# %%
! wget https://www.kotzendes-einhorn.de/blog/wp-content/uploads/2011/01/lenna.jpg
# Out:
# --2020-05-11 15:19:37--  https://www.kotzendes-einhorn.de/blog/wp-content/uploads/2011/01/lenna.jpg
# Resolving www.kotzendes-einhorn.de (www.kotzendes-einhorn.de)... 94.130.145.107
# Connecting to www.kotzendes-einhorn.de (www.kotzendes-einhorn.de)|94.130.145.107|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64098 (63K) [image/jpeg]
# Saving to: ‘lenna.jpg.1’
#
# lenna.jpg.1         100%[===================>]  62.60K  --.-KB/s    in 0.1s
#
# 2020-05-11 15:19:38 (444 KB/s) - ‘lenna.jpg.1’ saved [64098/64098]

# %%
# sns.set_style(style='white')

img = plt.imread('./lenna.jpg')

plt.figure(figsize=(12,7))
plt.imshow(img);

# %% [markdown]
# Функция для инициализации весов слоя:

# %%
def init_conv(kernel):
    conv = nn.Conv2d(
        in_channels=3, out_channels=1, 
        kernel_size=3, bias=False
    )
    conv.weight = torch.nn.Parameter(
        torch.FloatTensor(kernel), 
        requires_grad=False
    )
    return conv

# %% [markdown]
# Функция для свертки изображения с одним фильтром:

# %%
def convolution(kernel, img, transforms):
    conv = init_conv(kernel)
    img_tensor = transform(img)
    # добавим батч-размерность
    res = conv(img_tensor.unsqueeze(0))
    res = res.detach().squeeze().numpy()
    # пиксели имеют значения от 0 до 255
    res = (np.clip(res, 0, 1)*255).astype(int)
    return res

# %% [markdown]
# Numpy-картинку нужно привести к torch-тензору:

# %%
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Grayscale(), 
    transforms.ToTensor()
])

# %% [markdown]
# Зададим фильтры:

# %%
kernel_1 = torch.FloatTensor([[[
    [-1, 0, 1],
    [-1, 0, 1],
    [-1, 0, 1]
]]])

kernel_2 = torch.FloatTensor([[[
    [-1, -1, -1],
    [0, 0, 0],
    [1, 1, 1]
]]])

# %%
sns.set_style(style='white')

fig, ax = plt.subplots(
    nrows=1, ncols=2, figsize=(16, 7), 
    sharey=True, sharex=True
)

res_images = []
for fig_x, kernel in zip(ax.flatten(), [kernel_1, kernel_2]):
    res = convolution(kernel, img, transform)
    fig_x.imshow(res, cmap='gray')
    res_images.append(res)
plt.suptitle('Фильтры (операторы) Собеля')
plt.show()

# %% [markdown]
# Чем более пиксель белый, тем больше его значение. Если присмотреться, то можно заметить, как на первом результате фильтр (ядро) делает более значимыми (белыми) пиксели, соответствующие вертикальным линиям: нос, полоска справа, волосы, а на втором $-$ горизонтальным: брови, губы.
#
# Это как раз согласуется со значениями в фильтрах (ядрах): первый вычисляет перепады значений в пикселях по вертикали, второй $-$ по горизонтали.
#
# С помощью этих фильтров легко прийти к методу выделения границ на изображении: поскольку каждая граница состоит из $x$ и $y$ компоненты, то используем теорему Пифагора и вычислим суммарное значение:

# %%
img_sobel = np.sqrt(res_images[0]**2 + res_images[1]**2)

plt.figure(figsize=(12,7))
plt.title('Выделение границ')
plt.imshow(img_sobel, cmap='gray')
plt.show()

# %% [markdown]
# Этот метод называет также [оператором Собеля](https://ru.wikipedia.org/wiki/%D0%9E%D0%BF%D0%B5%D1%80%D0%B0%D1%82%D0%BE%D1%80_%D0%A1%D0%BE%D0%B1%D0%B5%D0%BB%D1%8F). Так, мы посмотрели как работает свертка на примере оператора Собеля.

# %% [markdown]
# ### Pooling
#
# Основные гиперпараметры:
#
# * `kernel_size` (int, tuple) - размер ядра
#
# * `stride` (int, tuple) - шаг, с которым будет применен pooling. Значение по умолчанию `kernel_size`
#
# * `padding` (int, tuple) - добавление по краям изображения нулей
#
# Основные виды pooling-ов: `MaxPooling` (берется максимум элементов), `AveragePooling` (берется среднее элементов).
#
# ![](https://sun9-10.userapi.com/c854016/v854016674/22a457/mpE8Idra-5Y.jpg)
#
# **Интуиция:**
#
# 1. cнижаем размерность изображения и, как следствие, вычислительную сложность
#
# 2. увеличиваем рецептивное поле на входном изображении для нейронов следующих сверточных слоев
#
# При этом многие исследователи ставят под сомнение эффективность pooling слоёв. Например, в статье [Striving for Simplicity: The All Convolutional Net](https://arxiv.org/abs/1412.6806) предлагается заменить его на свертки с большим stride-ом. Также считается, что отсутствие pooling слоёв хорошо сказывается на обучении генеративных моделей, но споры ещё ведутся: [FCC-GAN: A Fully Connected and Convolutional Net
# Architecture for GANs](https://arxiv.org/pdf/1905.02417.pdf)
#
#
# **Вопрос:** сколько параметров у pooling слоя?

# %% [markdown]
# Применим наши знания для решения конкретной задачи:

# %% [markdown]
# ##  CIFAR10
#
# Датасет состоит из 60k картинок 32х32х3.
#
# 50k - обучающая выборка, 10k - тестовая.
#
# 10 классов: 'plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck'.
#
#  ![](https://sun9-72.userapi.com/c857216/v857216523/12dbca/vdSCet5LS_0.jpg)

# %% [markdown]
# Загружаем датасет:

# %%
dataset = torchvision.datasets.CIFAR10(
    root='./data', 
    train=True,
    download=True, 
    transform=transforms.ToTensor()
)
# разделили выборку на обучение и валидацию
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [40000, 10000])

test_dataset = torchvision.datasets.CIFAR10(
    root='./data', 
    train=False,
    download=True, 
    transform=transforms.ToTensor()
)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# Инициализируем генераторы батчей:

# %%
batch_size = 64

train_batch_gen = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_batch_gen = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
test_batch_gen = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# Пайплайн обучения:

# %%
def plot_learning_curves(history):
    '''
    Функция для обучения модели и вывода лосса и метрики во время обучения.

    :param history: (dict)
        accuracy и loss на обучении и валидации
    '''
    # sns.set_style(style='whitegrid')
    fig = plt.figure(figsize=(20, 7))

    plt.subplot(1,2,1)
    plt.title('Лосс', fontsize=15)
    plt.plot(history['loss']['train'], label='train')
    plt.plot(history['loss']['val'], label='val')
    plt.ylabel('лосс', fontsize=15)
    plt.xlabel('эпоха', fontsize=15)
    plt.legend()

    plt.subplot(1,2,2)
    plt.title('Точность', fontsize=15)
    plt.plot(history['acc']['train'], label='train')
    plt.plot(history['acc']['val'], label='val')
    plt.ylabel('лосс', fontsize=15)
    plt.xlabel('эпоха', fontsize=15)
    plt.legend()
    plt.show()

# %% [markdown]
# Функция для обучения нейросети:

# %%
def train(
    model, 
    criterion,
    optimizer, 
    train_batch_gen,
    val_batch_gen,
    num_epochs=50
):
    '''
    Функция для обучения модели и вывода лосса и метрики во время обучения.

    :param model: обучаемая модель
    :param criterion: функция потерь
    :param optimizer: метод оптимизации
    :param train_batch_gen: генератор батчей для обучения
    :param val_batch_gen: генератор батчей для валидации
    :param num_epochs: количество эпох

    :return: обученная модель
    :return: (dict) accuracy и loss на обучении и валидации ("история" обучения)
    '''

    history = defaultdict(lambda: defaultdict(list))

    for epoch in range(num_epochs):
        train_loss = 0
        train_acc = 0
        val_loss = 0
        val_acc = 0
        
        start_time = time.time()

        # Устанавливаем поведение dropout / batch_norm  в обучение
        model.train(True) 

        # На каждой "эпохе" делаем полный проход по данным
        for X_batch, y_batch in train_batch_gen:
            # Обучаемся на батче (одна "итерация" обучения нейросети)
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)
            
            logits = model(X_batch)
            
            loss = criterion(logits, y_batch.long().to(device))

            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            
            train_loss += np.sum(loss.detach().cpu().numpy())
            y_pred = logits.max(1)[1].detach().cpu().numpy()
            train_acc += np.mean(y_batch.cpu().numpy() == y_pred)

        # Подсчитываем лоссы и сохраням в "историю"
        train_loss /= len(train_batch_gen)
        train_acc /= len(train_batch_gen) 
        history['loss']['train'].append(train_loss)
        history['acc']['train'].append(train_acc)
    
        # Устанавливаем поведение dropout / batch_norm в режим тестирования
        model.train(False) 

        # Полный проход по валидации    
        for X_batch, y_batch in val_batch_gen:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)
            
            logits = model(X_batch)
            loss = criterion(logits, y_batch.long().to(device))
            val_loss += np.sum(loss.detach().cpu().numpy())
            y_pred = logits.max(1)[1].detach().cpu().numpy()
            val_acc += np.mean(y_batch.cpu().numpy() == y_pred)

        # Подсчитываем лоссы и сохраням в "историю"
        val_loss /= len(val_batch_gen)
        val_acc /= len(val_batch_gen) 
        history['loss']['val'].append(val_loss)
        history['acc']['val'].append(val_acc)
        
        clear_output()

        # Печатаем результаты после каждой эпохи
        print("Epoch {} of {} took {:.3f}s".format(
            epoch + 1, num_epochs, time.time() - start_time))
        print("  training loss (in-iteration): \t{:.6f}".format(train_loss))
        print("  validation loss (in-iteration): \t{:.6f}".format(val_loss))
        print("  training accuracy: \t\t\t{:.2f} %".format(train_acc * 100))
        print("  validation accuracy: \t\t\t{:.2f} %".format(val_acc * 100))
        
        plot_learning_curves(history)
        
    return model, history

# %% [markdown]
# ### Baseline
#
# Начнем с простой линейной модели, рассмотренной на прошлом семинаре по нейросетям:

# %%
class MySimpleModel(nn.Module):
    def __init__(self):
        '''
        Здесь объявляем все слои, которые будем использовать
        '''

        super(MySimpleModel, self).__init__()
        # входное количество признаков = высота * ширина * кол-во каналов картинки
        # сейчас 64 нейрона в первом слое
        self.linear1 = nn.Linear(3 * 32 * 32, 64)
        # 10 нейронов во втором слое
        self.linear2 = nn.Linear(64, 10)  # логиты (logits) для 10 классов
        
    def forward(self, x):
        '''
        Здесь пишем в коде, в каком порядке какой слой будет применяться
        '''
        
        x = self.linear1(nn.Flatten()(x))
        x = self.linear2(nn.ReLU()(x))
        return x

# %% [markdown]
# Применим ее к нашим данным $-$ картинками из CIFAR10:

# %%
model = MySimpleModel().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

model, history = train(
    model, criterion, optimizer,
    train_batch_gen, val_batch_gen,
    num_epochs=50
)
# Out:
# Epoch 50 of 50 took 7.823s
#   training loss (in-iteration): 	1.290848
#   validation loss (in-iteration): 	1.449019
#   training accuracy: 			55.12 %
#   validation accuracy: 			49.60 %

# %% [markdown]
# ### Свёрточная нейросеть
#
# *Свёрточная нейросеть (Convolutional Neural Network, CNN)* - это многослойная нейросеть, имеющая в своей архитектуре свёрточные слои (Conv Layers) и pooling-слои (Pool Layers).
#
# Свёрточные нейросети (обыкновенные, есть и намного более продвинутые) почти всегда строятся по следующему правилу:
#
# $INPUT \to [[CONV -> RELU]^N \to POOL?]^M \to [FC -> RELU]^K \to FC$
#
# "?" обозначает опциональные слои.
#
# ![](https://sun9-64.userapi.com/c856028/v856028087/1eae7b/GrKeqELsvWM.jpg)
#
# Подробнее:
#
# 1). Входной слой (batch картинок HxWxC)
#
# 2).  $M$  блоков ($M  \ge  0$) из свёрток и pooling-ов. Все эти  $M$  блоков вместе называют *feature extractor* свёрточной нейросети, потому что эта часть сети отвечает непосредственно за формирование новых, более сложных признаков, поверх тех, которые подаются.
#
# При этом лучше использовать несколько сверток с маленьким рецептивным полем, чем одну свертку с большим рецептивным полем.
#
# 3).  $K$  штук FullyConnected-слоёв (с активациями). Эту часть из  $K$  FC-слоёв называют *classificator*, поскольку эти слои отвечают непосредственно за предсказание нужно класса (сейчас рассматривается задача классификации изображений).
#
# *Замечание*:  Pooling layer можно пропустить и не включать в архитектуру, но при этом он снижает размерность, а следовательно и вычислительную сложность, а также помогает бороться с переобучением
#
# **Пример, почему 3 свертки 3х3 экономнее по памяти, чем одна свертка 7x7:**
#
# Предположим, что входное изображение имеет $C$ каналов, и что количество фильтров в сверточных слоях тоже равно $C$.
#
# 1). **[CONV((3, 3)) -> RELU]^3**
#
# Количество параметров: $3(C(C*3*3)) = 27C^2$
#
# Рецептивное поле первой свертки на входном изображении: $3\times3$
#
# Рецептивное поле второй свертки на выходе первой свертки: $3\times3$, и, следовательно, $5\times5$ на входном изображении.
#
# Аналогично рецептивное поле третьей свертки (а значит и всего блока) на входном изображении: $7\times7$
#
#
# 2). **[CONV((7, 7)) -> RELU]^1**
#
# Количество параметров: $C(C*7*7) = 49C^2$
#
# Рецептивное поле на входном изображении: $7\times7$
#
# **Вывод:** Первый вариант формирует более сложные признаки из-за нелинейностей, при этом имеет меньше параметров и такое же рецептивное поле на входном изображении.

# %% [markdown]
# Также нужно не забывать о пользе `Dropout` и `BatchNorm`:
#
# * `Dropout` позволяет бороться с переобучением, можно интерпретировать как обучение ансамбля моделей
# * `BatchNorm` нормирует данные, делает веса на более поздних слоях менее чувствительными к изменениям весов на начальных слоях. Таким образом `BatchNorm` позволяет сделать нейросеть более стабильной при изменении распределения входных данных.

# %% [markdown]
# #### Задание:
#
#  Посмотрите на следующую нейросеть и укажите на некорректные шаги в реализации.

# %%
model = nn.Sequential()
model.add_module('conv1', nn.Conv2d(3, 2048, kernel_size=5, stride=2, padding=3))
model.add_module('mp1', nn.MaxPool2d(7))
model.add_module('conv2', nn.Conv2d(2048, 64, kernel_size=3))
model.add_module('mp2', nn.MaxPool2d(2))
model.add_module('bn1', nn.BatchNorm2d(64))
model.add_module('dp1', nn.Dropout(0.5))
model.add_module('relu1', nn.ReLU())

model.add_module('conv3', nn.Conv2d(64, 128, kernel_size=(20, 20)))
model.add_module('mp3', nn.MaxPool2d(2))
model.add_module('conv4', nn.Conv2d(128, 256, kernel_size=(20, 20)))

model.add_module('flatten', nn.Flatten())
model.add_module('fc1', nn.Linear(1024, 512))
model.add_module('fc2', nn.Linear(512, 10))
model.add_module('dp2', nn.Dropout(0.05))

# %% [markdown]
# > Подсказка:
#
# *(нужно дважды кликнуть на ячейку)*
# <style>
# div.input {
#
# * нет активаций после сверток (свертка по своей сути - линейное преобразование и активации нужны, чтобы добавить нелинейность)
#
# * слишком много выходных каналов в `conv1`. Увеличили число параметров слишком сильно: мы потратим гораздо больше времени на обучение при этом получив много повторяющихся сверток
#
# * теряем слишком много информации в `mp1`, размер ядра нужно уменьшить
#
# * теряем слишком много информации в `dp1`
#
# * слишком большой `kernel_size` в `conv3` и `conv4`, этот код не сможет скомпилироваться, потому что размер изображения будет меньше, чем `kernel_size`
#
# * два линейных слоя подряд `fc1` и `fc2` без активации между ними можно заменить одним синейным слоем
#
# * `droupout` в конце просто зануляет часть выходов к лоссу, а не выключает связи между нейронами. Тем самым мы теряем уже выученную информацию, а не боремся с переобучением.
# display:none;
# }
# </style>

# %% [markdown]
# #### Задание:
#
# На основе предыдущего примера:
# 1. Исправьте все ошибки и реализуйте свою сверточную сеть;
# 2. Обучите её и посмотрите на качество.
#
# Не забывайте о пользе `Dropout` и `BatchNorm`.

# %%
class SimpleConvNet(nn.Module):
    def __init__(self):
        # вызов конструктора предка
        super(SimpleConvNet, self).__init__()
#         <Ваш код здесь>
        self.conv1 = nn.Conv2d(3, 32, 3) 
        self.mp1 = nn.MaxPool2d(2)
        self.bn1 = nn.BatchNorm2d(32)
        self.droupout1 = nn.Dropout(0.3)
        self.relu1 = nn.ReLU()
        
        self.conv2 = nn.Conv2d(32, 64, 3)
        self.mp2 = nn.MaxPool2d(2)
        self.bn2 = nn.BatchNorm2d(64)
        self.droupout2 = nn.Dropout(0.3)
        self.relu2 = nn.ReLU()
        
        self.flatten = nn.Flatten()
        self.fc3 = nn.Linear(2304, 512)
        self.droupout3 = nn.Dropout(0.3)
        self.relu3 = nn.ReLU()
        self.fc4 = nn.Linear(512, 10)
                                
#         <Ваш код здесь>

    def forward(self, x):
#         <Ваш код здесь>
        layer1 = self.mp1(self.conv1(x))
        layer1 = self.relu1(self.droupout1(self.bn1(layer1)))
        
        layer2 = self.mp2(self.conv2(layer1))
        layer2 = self.relu2(self.droupout2(self.bn2(layer2)))
        
        out = self.flatten(layer2)
        out = self.relu3(self.droupout3(self.fc3(out)))
        out = self.fc4(out)
#         <Ваш код здесь>
        return out

# %%
model = SimpleConvNet().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

model, history = train(
    model, criterion, optimizer, 
    train_batch_gen, val_batch_gen, 
    num_epochs=50
)
# Out:
# Epoch 50 of 50 took 9.164s
#   training loss (in-iteration): 	0.474847
#   validation loss (in-iteration): 	0.664767
#   training accuracy: 			83.43 %
#   validation accuracy: 			76.95 %

# %% [markdown]
# > Сравните полученное качество с тем, что мы получили ранее для MLP.

# %% [markdown]
# ### Data augmentations
#
# ![](https://sun9-5.userapi.com/c857216/v857216818/1815e6/OxQ8e3-o0oU.jpg)
#
# Data augmentations - это метод, направленный на увеличение размеров обучающей выборки. Дополнение обучающей выборки разнообразными, "хорошими" и "плохими" примерами, позволяет получить модель более устойчивую на тестовых данных, так как для неё в тестовых данных будет меньше "неожиданностей".
#
# С помощью `torchvision.transforms` мы применим несколько случайных преобразований к картинкам и тем самым расширим нашу выборку. Про все реализованные в библиотеке преобразования можно почитать [здесь](https://pytorch.org/docs/stable/torchvision/transforms.html).
#
# В данном случае в качестве аугментации мы используем:
#
# * `ColorJitter` - изменение яркости, контраста, насыщенности цветов
# * `RandomAffine` - афинное преобразование

# %%
from torchvision import transforms


# набор аугментаций при обучении
transform_train = transforms.Compose([
    transforms.ColorJitter(0.9, 0.9, 0.9),
    transforms.RandomAffine( 5),
    transforms.ToTensor(),
])

# набор аугментаций при валидации
transform_test = transforms.Compose([
    transforms.ToTensor(),
])

# %% [markdown]
# Загружаем данные, но уже *с аугментациями*:

# %%
dataset = torchvision.datasets.CIFAR10(
    root='./data', 
    train=True,
    download=True, 
    transform=transform_train
)
# разделили выборку на обучение и валидацию
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [40000, 10000])

test_dataset = torchvision.datasets.CIFAR10(
    root='./data', 
    train=False,
    download=True, 
    transform=transform_test
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# Инициализируем даталоадеры:

# %%
batch_size = 64

train_batch_gen = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_batch_gen = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
test_batch_gen = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# Обучим нейросеть на новых данных:

# %%
model = SimpleConvNet().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

model, history = train(
    model, criterion, optimizer, 
    train_batch_gen, val_batch_gen, 
    num_epochs=50
)
# Out:
# Epoch 50 of 50 took 24.699s
#   training loss (in-iteration): 	0.945307
#   validation loss (in-iteration): 	0.950316
#   training accuracy: 			67.30 %
#   validation accuracy: 			68.29 %

# %% [markdown]
# Каждую эпоху для каждого изображения выбирается случайная трансформация. Таким образом каждую эпоху нейросеть обучается на одном и том же количестве изображений, но они каждый раз разные.

# %% [markdown]
# > Сравните, как аугментация влияет на качество на обучении и на валидации.

# %% [markdown]
# ## Transfer Learning
#
# [Transfer Learning](https://arxiv.org/abs/1808.01974v) - это процесс дообучения на *новых данных* какой-либо нейросети, предобученной до этого на других данных. Обычно предобучение производят на хорошем, большом (миллионы картинок) датасете (например, ImageNet ~ 14 млн картинок).
#
# На данный момент есть множество предобученных моделей: `AlexNet`, `DenseNet`, `ResNet`, `VGG`, `Inception` и другие, а также их различные модификации. Все они отличаются архитектурой и входными данными.

# %% [markdown]
# ### Описание метода:
#
# Представим, что eсть новый набор данных, и вы хотите научить сеть классифицировать объекты из этой выборки.
#
# * **1. Fine Tuning** (дообучение CNN)
#    * Берём сеть, обученную на ImageNet;
#    * Убираем последние Fully-Connected слои сети, отвечающие за классификацию;
#    * Размораживаем все или несколько предыдущих слоев сети (`param.requires_grad = True`), начиная с последнего (**не** с первого);
#    * Обучаем получившуюся архитектуру на новых данных (пару FC-слоёв, например).
#
# * **2. Feature Extractor** (CNN как средство для извлечения признаков)
#     * Берём сеть, обученную на ImageNet;
#     * Убираем последние Fully-Connected слои сети, отвечающие за классификацию;
#     * Замораживаем (`param.requires_grad = False`) веса всех предыдущих слоёв
#     * Обучаем на выходах полученной сети свой классификатор (пару FC-слоёв, например) на новых данных.
#
# Ниже эти подходы изображены на примере VGG архитектуры:
#
# <img src="https://sun9-66.userapi.com/c857632/v857632819/1ea161/rtU9L7NIrag.jpg" alt="tfl" width="600"/>
#
# <style>
# div.input {
#
# В зависимости от количества и природы Ваших данных есть выбор из **нескольких стратегий Transfer Learning**, а именно:
#
# * *У Вас **мало данных** ($\le 10k$), и они **похожи** на данные, на которых была обучена сеть до этого*
#
#     * если данные совсем похожи, можно попробовать использовать готовую модель
#     * если качество Вас не устраивает, то тогда стоит обратиться к методу Feature Extractor
#     * Fine Tuning лучше не использовать. Так как данные похожи на те, на которых обучалась сеть, то высокоуровневые признаки, полученные с помощью последних слоёв сети, должны оказаться информативными. Если делать в этом случае Fine-Tuning, то сеть может переобучиться, поскольку данных мало
#
# * *У Вас **мало данных** ($\le 10k$), и они **не похожи** на данные, на которых была обучена сеть до этого*
#     * в данном случае мы *не можем* ожидать от сети, что выходы последних слоёв будут информативными для новых данных. Следует использовать Feature Extractor, но брать как признаки выходы более ранних слоёв. Ведь, как ожидается, они соответствуют более общим паттернам в данных.
# * *У Вас **много данных** ($\ge 10k$), и они **похожи** на данные, на которых была обучена сеть до этого*
#     * можно попробовать использовать готовую модель
#     * если качество Вас не устраивает, то тогда стоит cделать Fine-Tuning, ведь данных много, и вероятность переобучения меньше. Имеет смысл попробовать разморохить веса последних нескольких слоёв (можно разморозить и всю сеть)
# * *У Вас **много данных** ($\ge 10k$), и они **не похожи** на данные, на которых была обучена сеть до этого*
#     * Fine-Tuning практически всей сети. Веса предобученной сети оставляют в качестве инициализации для обучения на новых данных
#
# display:none;
# }
# </style>

# %% [markdown]
# В зависимости от нового датасета имеет смысл использовать разные стратегии дообучения:
# - если датасет *похож* на тот, на котором модель предобучена, то возможно стоит просто заменить слой классификации;
# - если датасет *не похож*, то возможно стоит разморозить и сверточные слои тоже.
#
# **Эмпирическое правило**: *чем больше новый датасет не похож* на тот, на котором обучали модель, *тем больше слоев с конца стоит размораживать*.
#
# Если новый датасет достаточно большой (на каждый класс > 1000 изображений), то можно попробовать разморозить всю нейросеть и обучить со случайных весов, как мы это делали до того, как узнали про Transfer Learning.

# %% [markdown]
# Рассмотрим [**ResNet50**](https://arxiv.org/abs/1512.03385), предобученную на одном из самых крупных датасетов картинок ImageNet, который содержит 1000 классов. Подробнее про данный датасет можно почитать [здесь](http://image-net.org/}).
#
# Архитектура **ResNet50** основана на residual connections, которые позволяют избежать затухания градиентов:
#
# ![](https://sun9-72.userapi.com/c855620/v855620860/204ab7/DHbavFbU7QU.jpg)

# %% [markdown]
# Загрузим предобученную модель.

# %%
from torchvision.models import resnet50

model = resnet50(pretrained=True)  # скачиваем предобученные веса
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))

# %% [markdown]
# Скачаем названия классов для картинок из ImageNet.

# %%
# class labels
LABELS_URL = 'https://s3.amazonaws.com/outcome-blog/imagenet/labels.json'
labels = {int(key):value for (key, value) in requests.get(LABELS_URL).json().items()}

# %% [markdown]
#  Скачаем картинку альбатроса и посмотрим какой ответ дает предобученная сеть.

# %%
# !wget https://i.ibb.co/60RmQ6S/albatross.jpg -O albatross.jpg
# Out:
# --2020-05-10 21:08:03--  https://i.ibb.co/60RmQ6S/albatross.jpg
# Resolving i.ibb.co (i.ibb.co)... 206.221.176.29, 199.127.61.88
# Connecting to i.ibb.co (i.ibb.co)|206.221.176.29|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11607 (11K) [image/jpeg]
# Saving to: ‘albatross.jpg’
#
# albatross.jpg       100%[===================>]  11.33K  --.-KB/s    in 0s
#
# 2020-05-10 21:08:04 (160 MB/s) - ‘albatross.jpg’ saved [11607/11607]

# %% [markdown]
# Приведем картинку к нужному формату и напишем функцию для предсказания топ-10 классов для картинки.

# %%
from skimage.transform import resize

# приводим изображение к размеру 200х200
img = resize(plt.imread('albatross.jpg'), (200, 200))

# покажем получившуюся картинку
plt.imshow(img)
plt.axis('off')
plt.show()


def predict(img):
    '''
    Вывести 10 самых вероятных классов, согласно предсказания модели.

    '''
    model.train(False)

    # ! Обратите внимание на то, как картинка-`np.array` приводится к картинке-тензору
    img = torch.FloatTensor(img.reshape([1, 200, 200, 3]).transpose([0, 3, 1, 2]))
    
    # Софтмакс-преобразование логитов нейросети
    probs = torch.nn.functional.softmax(model(img), dim=-1)
    probs = probs.data.numpy()
    
    top_ix = probs.ravel().argsort()[-1:-10:-1]
    print ('top-10 classes are: \n [prob : class label]')
    for l in top_ix:
        print ('%.4f :\t%s' % (probs.ravel()[l], labels[l].split(',')[0]))
        

predict(img)
# Out:
# top-10 classes are:
#  [prob : class label]
# 0.9900 :	albatross
# 0.0042 :	spoonbill
# 0.0019 :	hammerhead
# 0.0013 :	American egret
# 0.0010 :	goose
# 0.0002 :	pelican
# 0.0002 :	oystercatcher
# 0.0001 :	crane
# 0.0001 :	black swan

# %% [markdown]
# #### Практика Transfer Learning: Симпсоны

# %% [markdown]
# Рассмотрим датасет "Симпсоны". Он скачивается в ячейке ниже, оригинал лежит по [ссылке](https://www.kaggle.com/alexattia/the-simpsons-characters-dataset/download).

# %%
# Альтернативно можно раскомментировать эту ячейку, загрузив свой kaggle.json из Kaggle.
# Для того, чтобы скачать kaggle.json, нужно войти в свой аккаунт 
# https://www.kaggle.com/<username>/account
# и нажать на "Create New Api Token" (Ctrl+F)

# !pip install -q kaggle
# from google.colab import files

# files.upload()

# ! mkdir ~/.kaggle
# ! cp kaggle.json ~/.kaggle/
# ! chmod 600 ~/.kaggle/kaggle.json
# ! kaggle datasets download -d alexattia/the-simpsons-characters-dataset
# ! unzip the-simpsons-characters-dataset.zip -d simpsons_dataset

# %%
import subprocess

def upload_file_from_gdrive(file_id, outfile):
    upload_cmd = (
        "wget --load-cookies /tmp/cookies.txt"
        " \"https://docs.google.com/uc?export=download&confirm=$("
        " wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies"
        f" --no-check-certificate 'https://docs.google.com/uc?export=download&id={file_id}'"
        f" -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\\1\\n/p')&id={file_id}\" "
        f" -O {outfile} && rm -rf /tmp/cookies.txt"
    )
    subprocess.check_call(upload_cmd, shell=True)

upload_file_from_gdrive(
    file_id='1yMJn1db-T7HETlVpKMkvhrcJ-_sT8JMx', 
    outfile='the-simpsons-characters-dataset.zip'
)

# %%
# !unzip the-simpsons-characters-dataset.zip -d simpsons_dataset
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0247.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0253.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0535.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1398.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0086.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0938.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0092.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0079.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1415.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1373.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1429.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0737.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0047.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0053.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0735.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1403.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1371.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1417.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0245.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0523.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0537.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0251.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0279.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1173.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0286.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0292.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0331.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0457.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0325.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0319.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0494.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0655.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0133.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0127.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0669.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1211.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1205.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0872.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0866.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0867.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0873.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0683.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1204.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1210.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1238.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0126.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0640.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0898.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0481.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0495.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1012.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0324.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0456.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0293.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0287.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1199.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1172.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1166.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0278.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0536.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0250.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0522.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0913.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0907.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0091.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1370.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1416.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0708.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1402.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0052.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0734.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0046.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1358.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1303.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1317.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0021.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0960.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0974.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0784.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0948.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0790.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0579.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0223.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0545.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0551.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1129.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0586.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1075.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0419.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1049.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0343.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0380.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1277.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0633.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0141.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0814.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0828.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1288.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0196.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0182.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0183.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0829.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0197.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0801.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0815.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0140.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1262.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0168.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0381.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0395.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0342.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1048.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0418.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1060.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1074.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0593.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0587.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1128.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0222.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1114.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0578.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0785.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0975.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0034.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0746.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0008.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1316.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1302.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1300.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0778.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0988.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1328.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0036.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0022.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0977.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0793.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0208.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1116.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0234.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0552.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0220.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0591.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0585.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1062.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0426.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0432.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0397.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0618.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1260.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1274.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0142.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0156.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1248.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0630.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0817.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0181.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0194.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0180.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0816.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0802.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1249.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0631.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0143.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1275.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0619.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1261.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1088.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0396.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0382.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0433.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0355.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0341.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0427.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0369.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1077.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1063.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0584.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0547.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0221.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0235.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0553.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1103.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1117.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0209.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0786.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0792.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0976.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0023.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0745.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0989.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0751.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0037.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1329.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0779.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1315.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0033.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0755.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0741.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0999.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1339.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0027.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1311.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0769.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0796.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0782.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0972.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0966.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0557.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0231.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0225.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1113.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1107.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0594.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0580.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0351.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0437.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0379.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1073.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0392.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0147.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1259.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0635.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0153.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1265.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0609.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1271.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0184.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0190.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0806.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0812.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0813.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0807.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0191.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0185.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0608.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1264.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0634.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0152.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1258.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0620.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0393.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1099.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0387.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0378.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1066.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0350.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0344.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0595.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1106.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1112.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0224.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0542.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0556.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0230.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0967.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0973.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0783.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0797.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1304.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1310.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0768.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0998.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0740.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1338.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0032.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0754.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0742.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1448.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1306.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0018.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1312.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0959.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0781.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0540.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0226.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0232.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1104.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1110.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0568.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0583.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0597.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0434.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0352.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1058.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0420.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1070.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0391.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0150.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0636.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0622.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1272.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1266.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0193.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1299.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0811.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0810.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0838.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0186.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1298.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0192.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0179.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0623.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0145.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0637.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0409.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1071.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1059.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0421.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0353.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0582.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1111.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1105.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0233.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0555.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0541.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0227.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0970.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0964.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0794.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0780.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0958.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1313.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0019.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1307.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0025.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0982.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0996.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1450.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0772.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0941.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0969.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1120.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0202.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0564.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0376.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0410.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1097.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0148.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1295.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1280.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0161.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1096.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0405.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1041.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1055.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0217.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0559.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0954.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0940.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0767.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0029.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1445.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0983.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0995.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1453.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1335.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0981.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1447.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0771.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0003.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0765.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0956.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1137.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0215.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0573.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1080.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0605.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0177.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1282.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1296.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0188.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0176.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1240.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1095.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0348.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1056.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1042.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0566.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0572.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0228.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1308.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1320.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1446.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0980.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1452.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0774.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0760.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1318.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0006.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1330.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0990.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0984.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0204.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1132.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0238.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1126.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0402.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0370.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1046.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0358.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1287.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0827.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1293.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1292.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0198.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1286.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0629.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1245.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0173.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0167.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1090.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1053.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0359.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1047.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0239.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1133.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1331.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0013.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0005.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0011.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0950.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1125.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0373.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0367.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1086.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1253.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1247.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0818.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1290.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1284.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0819.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1246.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0170.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0616.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1087.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0400.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0548.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0212.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0206.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0945.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0986.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0010.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0762.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1427.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1355.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0063.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0936.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0507.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0513.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1194.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1037.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0329.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0467.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0659.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1221.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0843.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1220.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0894.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0300.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1195.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0506.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0260.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0248.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1142.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0937.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1397.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0089.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1340.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1381.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0909.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1197.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0458.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1034.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0100.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0840.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0667.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0897.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1237.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0883.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0317.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0288.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1196.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0505.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0539.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0920.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0934.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1419.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0707.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0075.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0717.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0071.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0918.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0930.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1384.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0515.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0267.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1145.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1192.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1019.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0461.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0475.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0449.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0111.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0887.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1227.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0878.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0844.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0879.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1232.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0892.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0104.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1024.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0306.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0460.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1150.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0266.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0514.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1385.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0925.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1391.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0058.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0716.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1344.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1146.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1191.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0310.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0476.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0462.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0112.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0890.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0846.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0885.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1219.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0477.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1190.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0517.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0271.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0265.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0926.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0098.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1423.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1345.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0073.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0701.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1379.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1348.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1162.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0268.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0452.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1200.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0136.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0650.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0687.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0686.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0645.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0123.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0137.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0889.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0679.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1201.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1215.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0321.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0453.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0335.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0309.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0282.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1163.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0731.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0043.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1361.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1407.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0069.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1411.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0727.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0900.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1388.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0928.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0519.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1149.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0243.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0525.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0294.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1015.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0445.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0323.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1029.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0486.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1217.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0690.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0685.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0861.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0652.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0646.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1028.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0450.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0322.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0478.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1000.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0242.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1148.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0256.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1160.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0083.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0915.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1438.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0726.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0732.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1362.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0736.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0050.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0093.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0911.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0534.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0508.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1164.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0285.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1038.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0326.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0332.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0642.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0681.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0870.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0864.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0694.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0680.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1213.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1207.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0131.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0496.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0482.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0333.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0327.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0441.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1165.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1171.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0904.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_0910.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1367.jpg
#   inflating: simpsons_dataset/simpsons_dataset/ned_flanders/pic_1401.jpg
# ...
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0937.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0089.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1197.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0458.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0100.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0840.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0667.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0897.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1237.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0883.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0317.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0288.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1196.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0505.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0539.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0920.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0934.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0707.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0075.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0717.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0918.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0930.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0515.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0267.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1145.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1192.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1019.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0475.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0449.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0111.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0887.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0878.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0844.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0879.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1232.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0892.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1024.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0306.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0460.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0514.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0925.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0058.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1146.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0476.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0462.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0112.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0890.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0846.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0885.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0517.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0265.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0098.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0073.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1162.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0268.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1200.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0650.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0687.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0686.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0137.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0889.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0679.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1215.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0321.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0453.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0335.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0309.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1163.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0731.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0043.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0069.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0243.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0294.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1015.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0445.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0323.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1029.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0486.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1217.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0690.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0685.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0861.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0646.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1028.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0450.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0322.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0478.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0242.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1148.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0256.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1160.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0915.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0726.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0732.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0736.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0050.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0093.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0911.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0534.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0508.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1164.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0285.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0326.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0642.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0870.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0864.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1213.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1207.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0496.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0482.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0333.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0327.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1165.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1171.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0904.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0910.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0045.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0051.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0721.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0709.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0090.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0906.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1167.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1198.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0443.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1013.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1007.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0480.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0899.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0696.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0682.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0668.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0654.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0132.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0318.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1006.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0330.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0244.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0085.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0720.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0035.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1115.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1061.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0357.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0431.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0425.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0394.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0169.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0155.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0627.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0800.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1289.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0626.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0154.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1276.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0424.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0550.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0236.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1100.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0791.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0949.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0961.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0752.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0020.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0750.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0744.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0963.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0546.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0340.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0354.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1089.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0803.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0195.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0157.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0625.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0590.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0543.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0219.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0345.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1067.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1098.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0621.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1270.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1072.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0436.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0422.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0026.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0024.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0030.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0795.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0965.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0971.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1138.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0346.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0408.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0385.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0144.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0178.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0839.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0805.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1273.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0384.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0390.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1065.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0347.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0596.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0569.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_1139.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0031.jpg
#   inflating: simpsons_dataset/simpsons_dataset/marge_simpson/pic_0743.jpg

# %%
train_dir = 'simpsons_dataset/simpsons_dataset'

# %% [markdown]
# Разделим данные на обучение и валидацию:

# %%
class SplitImageFolder():

    def __init__(self, train_dir):

        self.train_dir = train_dir
        self.train_val_files_path = glob.glob(f'{train_dir}/*/*.jpg')
        self.train_val_labels = [path.split('/')[-2] for path in self.train_val_files_path]

    def split(self, test_size=0.3):

        train_files_path, val_files_path = train_test_split(
            self.train_val_files_path, 
            test_size=test_size,
            stratify=self.train_val_labels
        )

        files_path = {'train': train_files_path, 'val': val_files_path}

        return files_path

# %%
files_path = SplitImageFolder(train_dir).split()

# %% [markdown]
# Минимальный размер изображения, с которым работает `ResNet50` $-$ $200\times200$.
#
# В компьютерном зрении часто возникает такая ситуация -- картинки в датасете разного размера и качества. Чаще всего их приводят к одному размеру, например, $256\times256$ или $512\times512$.
#
# Приведем все входные изображения к этому размеру с помощью `transforms.Resize`.

# %%
input_size = 200

train_transform = transforms.Compose([
    transforms.Resize(input_size),
    transforms.CenterCrop(input_size),
    transforms.ColorJitter(0.9, 0.9, 0.9),
    transforms.RandomAffine(5),
    transforms.ToTensor(),
])


val_transform = transforms.Compose([
    transforms.Resize(input_size),
    transforms.CenterCrop(input_size),
    transforms.ToTensor(),
])

train_dataset = torchvision.datasets.ImageFolder(
    train_dir, 
    transform=train_transform,
    is_valid_file=lambda x: x in files_path['train']
)

val_dataset = torchvision.datasets.ImageFolder(
    train_dir, 
    transform=val_transform,
    is_valid_file=lambda x: x in files_path['val']
)

# %%
print("Количество классов: ", len(train_dataset.classes))
# Out:
# Количество классов:  47

# %% [markdown]
# Визуализируем данные:

# %%
sns.set_style(style='white')

fig, ax = plt.subplots(
    nrows=2, ncols=3, figsize=(8, 6),
    sharey=True, sharex=True
)

for fig_x in ax.flatten():
    idx = np.random.randint(low=0, high=6000)
    img, label = val_dataset[idx]
    fig_x.set_title(val_dataset.classes[label])
    fig_x.imshow(img.numpy().transpose((1, 2, 0)))

# %% [markdown]
# Инициализируем даталоадеры:

# %%
batch_size = 64

train_batch_gen = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_batch_gen = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# #### Обучение своей нейросети

# %% [markdown]
# Обучим сверточную нейросеть из предыдущей части задания на новых данных:

# %%
simple_model = SimpleConvNet()

# нужно заменить FC слой после Flatten, так как размер входного изображения стал больше
simple_model.fc3 = nn.Linear(147456, 512)
simple_model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(simple_model.parameters(), lr=0.01)

simple_model, history = train(
    simple_model, criterion, optimizer, 
    train_batch_gen, val_batch_gen, 
    num_epochs=30
)
# Out:
# Epoch 6 of 30 took 152.147s
#   training loss (in-iteration): 	1.986209
#   validation loss (in-iteration): 	2.008739
#   training accuracy: 			9.27 %
#   validation accuracy: 			14.69 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-18dc5e22efc0> in <module>()
#      10     simple_model, criterion, optimizer,
#      11     train_batch_gen, val_batch_gen,
# ---> 12     num_epochs=30
#      13 )
#
# <ipython-input-19-2efde1fabfda> in train(model, criterion, optimizer, train_batch_gen, val_batch_gen, num_epochs)
#      24
#      25         # На каждой "эпохе" делаем полный проход по данным
# ---> 26         for X_batch, y_batch in train_batch_gen:
#      27             # Обучаемся на батче (одна "итерация" обучения нейросети)
#      28             X_batch = X_batch.to(device)
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     343
#     344     def __next__(self):
# --> 345         data = self._next_data()
#     346         self._num_yielded += 1
#     347         if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     383     def _next_data(self):
#     384         index = self._next_index()  # may raise StopIteration
# --> 385         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     386         if self._pin_memory:
#     387             data = _utils.pin_memory.pin_memory(data)
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/folder.py in __getitem__(self, index)
#     133         """
#     134         path, target = self.samples[index]
# --> 135         sample = self.loader(path)
#     136         if self.transform is not None:
#     137             sample = self.transform(sample)
#
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/folder.py in default_loader(path)
#     169         return accimage_loader(path)
#     170     else:
# --> 171         return pil_loader(path)
#     172
#     173
#
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/folder.py in pil_loader(path)
#     152     with open(path, 'rb') as f:
#     153         img = Image.open(f)
# --> 154         return img.convert('RGB')
#     155
#     156
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in convert(self, mode, matrix, dither, palette, colors)
#     871         """
#     872
# --> 873         self.load()
#     874
#     875         if not mode and self.mode == "P":
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFile.py in load(self)
#     249
#     250                             b = b + s
# --> 251                             n, err_code = decoder.decode(b)
#     252                             if n < 0:
#     253                                 break
#
# KeyboardInterrupt:

# %% [markdown]
# #### Fine Tuning сети ResNet50

# %%
# summary(fine_tuning_model.to(device), (3, 200, 200))

# %% [markdown]
# Снова инициализируем даталоадеры, так как они являются генераторами:

# %%
batch_size = 32

train_batch_gen = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_batch_gen = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# Добавляем новые слои классификации под датасет Симпсонов (47 классов):

# %%
fine_tuning_model = nn.Sequential()

# предобученная на датасете ImageNet нейросеть ResNet50
fine_tuning_model.add_module('resnet', resnet50(pretrained=True))

# добавляем 2 FC слоя после выходов предобученной неросети
fine_tuning_model.add_module('relu_1', nn.ReLU())
fine_tuning_model.add_module('fc_1', nn.Linear(1000, 512))
fine_tuning_model.add_module('relu_2', nn.ReLU())
fine_tuning_model.add_module('fc_2', nn.Linear(512, 47))

fine_tuning_model = fine_tuning_model.to(device)

# %% [markdown]
# Убедимся, что все параметры сети "разморожены", то есть являются обучаемыми:

# %%
for param in fine_tuning_model.parameters():
    assert(param.requires_grad)
    assert(param.is_cuda)

# %% [markdown]
# Зафайнтюним эту модель на наших данных:

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(fine_tuning_model.parameters(), lr=0.01)

fine_tuning_model, history = train(
    fine_tuning_model, criterion, optimizer, 
    train_batch_gen, val_batch_gen, 
    num_epochs=5
)
# Out:
# Epoch 5 of 5 took 446.718s
#   training loss (in-iteration): 	0.092902
#   validation loss (in-iteration): 	0.149881
#   training accuracy: 			97.63 %
#   validation accuracy: 			96.62 %

# %% [markdown]
# > Сравните результаты и сделайте вывод.

# %% [markdown]
# #### Feature Extractor сети ResNet50

# %% [markdown]
# Заменяем последний слой классификатора на линейный классификатор, заморозим все остальные слои:

# %%
clf_model = resnet50(pretrained=True)

# "замораживаем" все веса всех слоев
for param in clf_model.parameters():
    param.requires_grad = False

# этоn слой будет обучаемым
clf_model.fc = nn.Linear(2048, 47)
clf_model = clf_model.to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(clf_model.parameters(), lr=0.01)

clf_model, history = train(
    clf_model, criterion, optimizer, 
    train_batch_gen, val_batch_gen, 
    num_epochs=50
)
# Out:
# Epoch 10 of 50 took 253.390s
#   training loss (in-iteration): 	1.538995
#   validation loss (in-iteration): 	1.317338
#   training accuracy: 			58.92 %
#   validation accuracy: 			65.10 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-e662971af968> in <module>()
#       5     clf_model, criterion, optimizer,
#       6     train_batch_gen, val_batch_gen,
# ----> 7     num_epochs=50
#       8 )
#
# <ipython-input-15-af15e43cd2f2> in train(model, criterion, optimizer, train_batch_gen, val_batch_gen, num_epochs)
#      24
#      25         # На каждой "эпохе" делаем полный проход по данным
# ---> 26         for X_batch, y_batch in train_batch_gen:
#      27             # Обучаемся на батче (одна "итерация" обучения нейросети)
#      28             X_batch = X_batch.to(device)
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     343
#     344     def __next__(self):
# --> 345         data = self._next_data()
#     346         self._num_yielded += 1
#     347         if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     383     def _next_data(self):
#     384         index = self._next_index()  # may raise StopIteration
# --> 385         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     386         if self._pin_memory:
#     387             data = _utils.pin_memory.pin_memory(data)
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/folder.py in __getitem__(self, index)
#     135         sample = self.loader(path)
#     136         if self.transform is not None:
# --> 137             sample = self.transform(sample)
#     138         if self.target_transform is not None:
#     139             target = self.target_transform(target)
#
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      59     def __call__(self, img):
#      60         for t in self.transforms:
# ---> 61             img = t(img)
#      62         return img
#      63
#
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#     923         transform = self.get_params(self.brightness, self.contrast,
#     924                                     self.saturation, self.hue)
# --> 925         return transform(img)
#     926
#     927     def __repr__(self):
#
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      59     def __call__(self, img):
#      60         for t in self.transforms:
# ---> 61             img = t(img)
#      62         return img
#      63
#
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#     311
#     312     def __call__(self, img):
# --> 313         return self.lambd(img)
#     314
#     315     def __repr__(self):
#
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/transforms.py in <lambda>(img)
#     898         if contrast is not None:
#     899             contrast_factor = random.uniform(contrast[0], contrast[1])
# --> 900             transforms.append(Lambda(lambda img: F.adjust_contrast(img, contrast_factor)))
#     901
#     902         if saturation is not None:
#
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/functional.py in adjust_contrast(img, contrast_factor)
#     626         raise TypeError('img should be PIL Image. Got {}'.format(type(img)))
#     627
# --> 628     enhancer = ImageEnhance.Contrast(img)
#     629     img = enhancer.enhance(contrast_factor)
#     630     return img
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageEnhance.py in __init__(self, image)
#      65     def __init__(self, image):
#      66         self.image = image
# ---> 67         mean = int(ImageStat.Stat(image.convert("L")).mean[0] + 0.5)
#      68         self.degenerate = Image.new("L", image.size, mean).convert(image.mode)
#      69
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in convert(self, mode, matrix, dither, palette, colors)
#     993
#     994         try:
# --> 995             im = self.im.convert(mode, dither)
#     996         except ValueError:
#     997             try:
#
# KeyboardInterrupt:

# %% [markdown]
# > Сравните результаты Fine Tuning и Feature Extractor способов и сделайте выводы.

# %% [markdown]
# ### Нейросетевые дескрипторы
#
# Для того, чтобы получить признаковое представление для обучения модели, нужно заменить последний слой классификатора на слой, который ничего не делает.
#
# То есть оставить тензор признаков как выход нейросети:

# %%
class Identity(torch.nn.Module):
    def __init__(self):
        super(Identity, self).__init__()

    def forward(self, x):
        return x

# %%
extractor_model = resnet50(pretrained=True)
extractor_model.fc = Identity()

extractor_model.train(False)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Identity()
# )

# %% [markdown]
# Снова инициализируем даталоадеры:

# %%
batch_size = 1

train_batch_gen = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_batch_gen = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# Берем нейросетевые признаки с последнего слоя, сохраняя их в переменную `X`:

# %%
X = []
Y = []

# то же самое, что и `extractor_model.eval()`
extractor_model.train(False)

# извлекаем признаки из обучающей выборки
for i, (image_batch, label_batch) in tqdm(enumerate(train_batch_gen), 
                                          total=len(train_dataset)/batch_size):
    features = extractor_model(image_batch).detach()
    X.append(features)
    Y.append(label_batch)
    if i == 100:
        break

# извлекаем признаки из валидационной выборки
for i, (image_batch, label_batch) in tqdm(enumerate(val_batch_gen), 
                                          total=len(val_dataset)/batch_size):
    features = extractor_model(image_batch).detach()
    X.append(features)
    Y.append(label_batch)
    if i == 10:
        break
# Out:
# HBox(children=(IntProgress(value=0, max=14653), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6280), HTML(value='')))

# %%
Y = np.array(Y)
X = np.concatenate(X)

print(X.shape, Y.shape)
# Out:
# (112, 2048) (112,)

# %% [markdown]
# Мы получили признаковое описание объектов и теперь можем работать с ними как с обычным датасетом.

# %% [markdown]
# ---
